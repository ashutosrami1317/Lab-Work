# %% [markdown]
# <h1 style="fond-size:30px;">Lab Work 1.1</h1>

# %%
print("name:[Ashutosh rami]")
print("age:[21]")
print("city:[Gadhinager]")
# Out:
# name:[Ashutosh rami]
# age:[21]
# city:[Gadhinager]

# %%
print("*")
print("**")
print("***")
print("****")
print("*****")
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# <h1 style="fond-size:30px;">Lab Work 1.2</h1>

# %%
print("apple","Banana","chery",sep="-")
print("This is the frist line.",end=" ")
print("This stays on the same line.")
# Out:
# apple-Banana-chery
# This is the frist line. This stays on the same line.

# %%
name = input("Enter your name:")
age = input("Enter your age:")
hobby = input("Enter ypur hobby:")
# Out:
# Enter your name: Ashutosh
# Enter your age: 21
# Enter ypur hobby: crickt

# %%
a = int(input("Enter frist number:"))
b = int(input("Enter second number:"))

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# Enter frist number: 20
# Enter second number: 15
# 35
# 5
# 300
# 1.3333333333333333
# 1
# 5
# 32768000000000000000

# %%
height = input("Enter your height:")
weight = input("Enter your weight:")
print(f"your recorded height is {height} and your weight is {weight}kg.")
# Out:
# Enter your height: 167.3
# Enter your weight: 85
# your recorded height is 167.3 and your weight is 85kg.

# %%
x = input("Enter frist boolean (True/False):")
y = input("Enter second boolean (True/False):")
print(x and y)
print([x or y])
print(not[x],not[y])
# Out:
# Enter frist boolean (True/False): x
# Enter second boolean (True/False): y
# y
# ['x']
# False False

# %%
value = 5
print(value)
value += 5
print(value)
value -= 3
print(value)
value *= 4
print(value)
value /= 6
print(value)
# Out:
# 5
# 10
# 7
# 28
# 4.666666666666667

# %% [markdown]
# <h1 style="fond-size:30px;">Lab work 1.3</h1>

# %%
user_input = input("Enter a value")
val_int = int(user_input)
val_float = float(user_input)
val_bool = bool(user_input)
print(f"integer:{val_int}")
print(f"floar:{val_float}")
print(f"Bool:{val_bool}")
# Out:
# Enter a value 45
# integer:45
# floar:45.0
# Bool:True

# %%
num_float = float(input("Enter a float"))
num_int = int(num_float)
print(f"original float:{num_float}")
print(f"Converted Integer:{num_int}")
# Out:
# Enter a float 11
# original float:11.0
# Converted Integer:11

# %%
val_bool = input("Enter True or False:") == True
val_int = int(val_bool)
val_str = str(val_bool)
print(f"Bool: {val_bool}, int: {val_bool}, string {val_bool}")
# Out:
# Enter True or False: 34.67
# Bool: False, int: False, string False

# %%
a = 10
b = 2.5
c = "Hi"
d = True
e = [2,3]
f = (78,98)
g = {"x":1}

print(a,type(a),id(a))
print(b,type(b),id(b))
print(c,type(c),id(c))
print(d,type(d),id(d))
print(e,type(e),id(e))
print(f,type(f),id(f))
print(g,type(g),id(g))
# Out:
# 10 <class 'int'> 140709178352840
# 2.5 <class 'float'> 2687531457008
# Hi <class 'str'> 2687532569952
# True <class 'bool'> 140709177440736
# [2, 3] <class 'list'> 2687485572160
# (78, 98) <class 'tuple'> 2687532522496
# {'x': 1} <class 'dict'> 2687532695168

# %%
a = 10
b = 45
print(id(a),id(b))

a = 23
print(id(a),id(b))
# Out:
# 140709178352840 140709178353960
# 140709178353256 140709178353960
