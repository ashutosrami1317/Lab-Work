# %%
# print("Welcome to the Date Analyzer and Transformer program")

while True:
    print("\n Main Menu:")
    print("1.Input Data")
    print("2.Display Data sumay")
    print("3.Calculate Factorial")
    print("4.Filter Data by Threshold")
    print("5.Sort Data")
    print("6.Display Dataset statistics")
    print("7.Exit Program")

    try:
        choice = int(input("Enter your choice:"))
    except valueError:
        print("Please enter a valid number!")
        continue

        # Input data
       if choice == '1':
           user_input = input(12,34,67,87,23,99,89,99)
           data = [int(x) for x in user_input.split()]
           print("Data has been stored successfully!")

       elif choice == '2':
           if data :
               dispaly_sumay(
                   total_elements=len(data),
                   minimum_valu=min(data),
                   maximum_valu=max(data),
                   sum_of_all_values=sum(data),
                   
               )
           else:
               print("No data available.")
       elif choice == '3':
# Out:
# Welcome to the Date Analyzer and Transformer program
#
#  Main Menu:
# 1.Input Data
# 2.Display Data sumay
# 3.Calculate Factorial
# 4.Filter Data by Threshold
# 5.Sort Data
# 6.Display Dataset statistics
# 7.Exit Program
# Enter your choice: 1
#  Main Menu:
# 1.Input Data
# 2.Display Data sumay
# 3.Calculate Factorial
# 4.Filter Data by Threshold
# 5.Sort Data
# 6.Display Dataset statistics
# 7.Exit Program
# Enter your choice: 1
#  Main Menu:
# 1.Input Data
# 2.Display Data sumay
# 3.Calculate Factorial
# 4.Filter Data by Threshold
# 5.Sort Data
# 6.Display Dataset statistics
# 7.Exit Program
# Enter your choice: 1
#  Main Menu:
# 1.Input Data
# 2.Display Data sumay
# 3.Calculate Factorial
# 4.Filter Data by Threshold
# 5.Sort Data
# 6.Display Dataset statistics
# 7.Exit Program
# Enter your choice: 2
#  Main Menu:
# 1.Input Data
# 2.Display Data sumay
# 3.Calculate Factorial
# 4.Filter Data by Threshold
# 5.Sort Data
# 6.Display Dataset statistics
# 7.Exit Program
