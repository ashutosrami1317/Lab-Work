# %% [markdown]
# <h1>User Defined Function</h1>

# %%
# # TNRN - Take Nothing Return Nothing

# # function definition

# def myInfo():
#     print("\n\nHello Everyone.!!")
#     print("My Name is Ashutosh Rami.");
#     print("I am from Gandhinagar Gujarat.")
#     print("My Favourite Programming Language is Python.")

# # function calling
# myInfo()
# print("\nHello Jayanti Thakor")

# myInfo()
# myInfo()


def myInfo(name,city,lang):
    print("\n\nHello Everyone.!!")
    print(f"My Name is {name}.");
    print(f"I am from {city} Gujarat.")
    print(f"My Favourite Programming Language is {lang}.")

# function calling
myInfo("Jayanti Thakor","Gandhinagar","JavaScript")
myInfo("Ashutosh Rami","Surat","Python")
# print("\nHello Jayanti Thakor")
# Out:
# Hello Everyone.!!
# My Name is Jayanti Thakor.
# I am from Gandhinagar Gujarat.
# My Favourite Programming Language is JavaScript.
#
#
# Hello Everyone.!!
# My Name is Ashutosh Rami.
# I am from Surat Gujarat.
# My Favourite Programming Language is Python.

# %%
def Ai():
    print("hello i'am will")
    print("my language paython")

Ai()
# Out:
# hello i'am will
# my language paython

# %%
def number():
    print(0)
    print(123)
    print(1317)

number()
# Out:
# 0
# 123
# 1317

# %%
def x(t):
    print(f"{t}Rs.")

x(1200)
# Out:
# 1200Rs.

# %%
def number(n):
    print(f"{n}%")
    print(f"{n}*")
    print(f"{n}/")
    print(f"{n}?")

number(12)
number(45)
number(12.45)
number(-123)
# Out:
# 12%
# 12*
# 12/
# 12?
# 45%
# 45*
# 45/
# 45?
# 12.45%
# 12.45*
# 12.45/
# 12.45?
# -123%
# -123*
# -123/
# -123?

# %%
number(12)
# Out:
# 12%
# 12*
# 12/
# 12?

# %%
def z(a,b,c):
    print(f"{a+b+c}")

z(34,56,67)
# Out:
# 157

# %%
def disple(
